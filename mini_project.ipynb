# %%
import pandas as pd
data=pd.read_csv('https://raw.githubusercontent.com/Shreyas3108/house-price-prediction/master/kc_house_data.csv')
data
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 10))
sns.jointplot(x=data.lat.values, y=data.long.values, height=10)
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine()

# %%
plt.scatter(data.price, data.sqft_living)
plt.title("Price vs Square Feet", fontsize=20)
plt.xlabel("Square Feet", fontsize=15)
plt.ylabel("Price", fontsize=15)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(data.price,data.long)
plt.title("Price vs Location of the area")
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.scatter(data.price,data.lat)
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(data.bedrooms,data.price)
plt.title("Bedroom and Price ")
plt.xlabel("Bedrooms")
plt.ylabel("Price")
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']),data['price'])

# %%
plt.scatter(data.waterfront,data.price)
plt.title("Waterfront vs Price ( 0= no waterfront)")
# Out:
# Text(0.5, 1.0, 'Waterfront vs Price ( 0= no waterfront)')

# %%
train1 = data.drop(['id', 'price'],axis=1)

# %%
train1.head()
# Out:
#               date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  20141013T000000         3       1.00         1180      5650     1.0
# 1  20141209T000000         3       2.25         2570      7242     2.0
# 2  20150225T000000         2       1.00          770     10000     1.0
# 3  20141209T000000         4       3.00         1960      5000     1.0
# 4  20150218T000000         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
data.floors.value_counts().plot(kind='bar')
plt.title('number of floors',fontsize='20')
plt.grid()

# %%
plt.scatter(data.floors,data.price)
plt.grid()
plt.title("Floors vs Price", fontsize=15)
plt.xlabel("Floors", fontsize=15)
plt.ylabel("Price", fontsize=15)
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(data.condition,data.price)

# %%
plt.scatter(data.zipcode,data.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
labels = data['price']
conv_dates = [1 if values == 2014 else 0 for values in data.date ]
data['date'] = conv_dates
train1 = data.drop(['id', 'price'],axis=1)

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test,y_test)
# Out:
# 0.7320342760357377

# %%
y_pred = reg.predict(x_test)
y_pred
# Out:
# array([ 708968.57473738, 1454115.56763587,  422619.27778289, ...,
#         191420.54893194,  238056.68598474,  451235.02573478])

# %%
y_train
# Out:
# 12826    1749000.0
# 6410      315000.0
# 15417     375000.0
# 16882     524000.0
# 8467      207000.0
#            ...
# 1099      151000.0
# 18898     325000.0
# 11798     905000.0
# 6637      313000.0
# 2575      690000.0
# Name: price, Length: 19451, dtype: float64

# %%
m=reg.coef_
c=reg.intercept_
print(m)
print(m)
# Out:
# [ 0.00000000e+00 -3.69584689e+04  3.99944474e+04  1.12442724e+02
#   1.05110204e-01  6.09005604e+03  6.03577974e+05  5.14093954e+04
#   2.61292108e+04  9.39146205e+04  7.03934445e+01  4.20492792e+01
#  -2.56363788e+03  1.97755242e+01 -5.81262588e+02  6.06931004e+05
#  -2.14720057e+05  2.18724560e+01 -3.52080103e-01]
# [ 0.00000000e+00 -3.69584689e+04  3.99944474e+04  1.12442724e+02
#   1.05110204e-01  6.09005604e+03  6.03577974e+05  5.14093954e+04
#   2.61292108e+04  9.39146205e+04  7.03934445e+01  4.20492792e+01
#  -2.56363788e+03  1.97755242e+01 -5.81262588e+02  6.06931004e+05
#  -2.14720057e+05  2.18724560e+01 -3.52080103e-01]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Assume your model has been trained and is available as 'reg'
# Define your input features as a DataFrame
input_features = pd.DataFrame({
    'bedrooms': [3],
    'bathrooms': [1.00],
    'sqft_living': [1180],
    'sqft_lot': [5650],
    'floors': [1.0],
    'waterfront': [0],
    'view': [0],
    'condition': [3],
    'grade': [7],
    'sqft_above': [1180],
    'sqft_basement': [0],
    'yr_built': [1955],
    'yr_renovated': [0],
    'zipcode': [98178],
    'lat': [47.5112],
    'long': [-122.257],
    'sqft_living15': [1340],
    'sqft_lot15': [5650],
    'date': [1]  # Example processed date feature
})

# Make sure the columns match the order used during training
input_features = input_features[train1.columns]

# Initialize the model (assuming it is already trained)
# reg = LinearRegression()
# reg.fit(x_train, y_train)  # This line should be done during training

# Make the prediction
prediction = reg.predict(input_features)

# Print the predicted value
print("Predicted value:", prediction[0])
# Out:
# Predicted value: 209088.70701579656

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

input_features = pd.DataFrame({
    'bedrooms': [4],
    'bathrooms': [1.75],
    'sqft_living': [1620],
    'sqft_lot': [4980],
    'floors': [1],
    'waterfront': [0],
    'view': [0],
    'condition': [4],
    'grade': [7],
    'sqft_above': [860],
    'sqft_basement': [760],
    'yr_built': [1947],
    'yr_renovated': [0],
    'zipcode': [98133],
    'lat': [47.7025],
    'long': [-122.341],
    'sqft_living15': [1400],
    'sqft_lot15': [4980],
    'date': [1]
})

input_features = input_features[train1.columns]

# Make the prediction
prediction = reg.predict(input_features)

# Print the predicted value
print("Predicted value:", prediction[0])
# Out:
# Predicted value: 469447.7554247156

# %%
m=reg.coef_
c=reg.intercept_
print(m)
print(m)
# Out:
# [ 0.00000000e+00 -3.69584689e+04  3.99944474e+04  1.12442724e+02
#   1.05110204e-01  6.09005604e+03  6.03577974e+05  5.14093954e+04
#   2.61292108e+04  9.39146205e+04  7.03934445e+01  4.20492792e+01
#  -2.56363788e+03  1.97755242e+01 -5.81262588e+02  6.06931004e+05
#  -2.14720057e+05  2.18724560e+01 -3.52080103e-01]
# [ 0.00000000e+00 -3.69584689e+04  3.99944474e+04  1.12442724e+02
#   1.05110204e-01  6.09005604e+03  6.03577974e+05  5.14093954e+04
#   2.61292108e+04  9.39146205e+04  7.03934445e+01  4.20492792e+01
#  -2.56363788e+03  1.97755242e+01 -5.81262588e+02  6.06931004e+05
#  -2.14720057e+05  2.18724560e+01 -3.52080103e-01]

# %%
import matplotlib.pyplot as plt

# Scatter plot of actual values vs. predicted values
plt.scatter(y_test, y_pred, color='blue', label='Predicted vs Actual')

# Plotting the best fit line (y = x)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linewidth=2, linestyle='--', label='Best Fit Line')

# Adding titles and labels
plt.title('Predicted Value vs Actual Value', fontsize=15)
plt.xlabel('Actual Value', fontsize=15)
plt.ylabel('Predicted Value', fontsize=15)
plt.legend()

# Show the plot
plt.show()
